# %%
import os

# 🔧 CHANGE THIS to your folder path
FOLDER_PATH = r"Coral Reef Images\train\Healthy"

# Supported image extensions
IMAGE_EXTENSIONS = (".jpg", ".jpeg", ".png", ".bmp", ".gif", ".webp")

# Get all image files
images = [
    f for f in os.listdir(FOLDER_PATH)
    if f.lower().endswith(IMAGE_EXTENSIONS)
]

# Sort to keep order predictable
images.sort()

print(f"Found {len(images)} image(s).")

# Rename images
for index, filename in enumerate(images, start=1):
    old_path = os.path.join(FOLDER_PATH, filename)
    new_name = f"{index}.jpg"
    new_path = os.path.join(FOLDER_PATH, new_name)

    os.rename(old_path, new_path)

print("Renaming completed.")
# Out:
# Found 1500 image(s).
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[20], line 26
#      23     new_name = f"{index}.jpg"
#      24     new_path = os.path.join(FOLDER_PATH, new_name)
# ---> 26     os.rename(old_path, new_path)
#      28 print("Renaming completed.")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Coral Reef Images\\train\\Healthy\\1007.jpg' -> 'Coral Reef Images\\train\\Healthy\\11.jpg'
